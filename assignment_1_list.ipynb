# %% [markdown]
# # Basic List Operations

# %% [markdown]
# 1. Create a list of 5 numbers and add a new number to the end.

# %%
list1 = [2, 5, 3, 4, 6]
list1.append(10)

list1
# Out:
# [2, 5, 3, 4, 6, 10]

# %% [markdown]
# 2. Make a list of fruits and insert a fruit at the second position.

# %%
fruits = ['Apple', 'Grapes', 'Pineapple']
fruits.insert(1, 'Cherry')

fruits
# Out:
# ['Apple', 'Cherry', 'Grapes', 'Pineapple']

# %% [markdown]
# 3. Create a list of names and remove one name from the list.

# %%
names = ['ABC', 'XYZ', 'PQR', 'LMN']
names.remove('XYZ')

names
# Out:
# ['ABC', 'PQR', 'LMN']

# %% [markdown]
# 4. Create a list of 4 items and change the value at index 2.

# %%
list2 = [23, 45, 65, 34, 54]
list2[2] =  00

list2
# Out:
# [23, 45, 0, 34, 54]

# %% [markdown]
# 5. Make a list of numbers and print only the first three elements.

# %%
nums = [1, 3, 4, 5, 5]
nums[0:3]
# Out:
# [1, 3, 4]

# %% [markdown]
# 6. Create a list of colors and find the index of a specific color.

# %%
colors = ['black', 'blue', 'red', 'white']
colors.index('red')
# Out:
# 2

# %% [markdown]
# 7. Create a list of 10 numbers and print how many times “5” appears.

# %%
num10 = [1, 2, 3, 5, 5, 6, 7, 5, 6, 9]

num10.count(5)
# Out:
# 3

# %% [markdown]
# 8. Make a list of 6 items and delete the item at index 3.

# %%
item6 = ['abc', 'qwe', 'rty', 'mnb', 'thu', 'bhu']
item = item6[2]

item
# Out:
# 'rty'

# %% [markdown]
# 9. Create a list of animals and add three more animals using extend().

# %%
list1 = ['lion', 'tiger']
list2 = ['leopard', 'elephant', 'panther']

list1.extend(list2)

list1
# Out:
# ['lion', 'tiger', 'leopard', 'elephant', 'panther']

# %% [markdown]
# 10. Create a list and remove the last item using pop().

# %%
pop_list = [1, 2, 3, 4, 5, 6]
pop_list.pop()

pop_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 11. Create a list of prices and sort them in ascending order.

# %%
price_list = [499, 399, 434, 233, 223]
sorted(price_list)
# Out:
# [223, 233, 399, 434, 499]

# %% [markdown]
# 12. Make a list of countries and reverse the order of the list.

# %%
countries = ['IN', 'USA', 'UK', 'UAE', 'SWE']
countries.reverse()

countries
# Out:
# ['SWE', 'UAE', 'UK', 'USA', 'IN']

# %% [markdown]
# 13. Create a list of words and check if “apple” is in the list.

# %%
words = ['asd', 'qwe', 'qaa', 'apple']

'apple' in words
# Out:
# True

# %% [markdown]
# 14. Create a list of numbers and print the largest and smallest number.

# %%
nums = [32, 34, 11, 9, 788]
print(max(nums))
print(min(nums))
# Out:
# 788
# 9

# %% [markdown]
# 15. Make a list of 5 items and print each item using a loop.

# %%
items5 = [23, 34, 45, 56, 67]

for i in items5:
    print(i, end=' ')
# Out:
# 23 34 45 56 67

# %% [markdown]
# 16. Create two lists and combine them into one list.

# %%
list1 = ['qwe', 'asd', 'zxc']
list2 = ['por', 'tgb']
list1.extend(list2)

list1
# Out:
# ['qwe', 'asd', 'zxc', 'por', 'tgb']

# %% [markdown]
# 17. Make a list and replace the last item with a new value.

# %%
liist = ['qwe', 'asd', 'zxc', 'poi', 'lkj', 'mno']
liist[-1] = 'xxx'

liist
# Out:
# ['qwe', 'asd', 'zxc', 'poi', 'lkj', 'xxx']

# %% [markdown]
# 18. Create a list of numbers and print only the even numbers.

# %%
even_list = [11, 21, 34, 44, 54, 56, 55]

for i in even_list:
    if i%2 == 0:
        print(i,end=' ')
# Out:
# 34 44 54 56

# %% [markdown]
# 19. Create a list and clear all items from the list.

# %%
new_list = [12, 23, 4, 45, 65, 67, 78]
new_list.clear()

new_list
# Out:
# []

# %% [markdown]
# 20. Create a list of 5 values and copy it into another list.

# %%
list5 = ['abc', 'def', 'ghi', 'jkl', 'mno']
copy_list = list5.copy()

copy_list
# Out:
# ['abc', 'def', 'ghi', 'jkl', 'mno']
